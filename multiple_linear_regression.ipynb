# %% [markdown]
# # mutiple linear regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('economic_index.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256
# 5           5  2017      7           2.50                5.6         1254
# 6           6  2017      6           2.50                5.5         1234
# 7           7  2017      5           2.25                5.5         1195
# 8           8  2017      4           2.25                5.5         1159
# 9           9  2017      3           2.25                5.6         1167

# %%
df.tail(15)
# Out:
#     Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 9            9  2017      3           2.25                5.6         1167
# 10          10  2017      2           2.00                5.7         1130
# 11          11  2017      1           2.00                5.9         1075
# 12          12  2016     12           2.00                6.0         1047
# 13          13  2016     11           1.75                5.9          965
# 14          14  2016     10           1.75                5.8          943
# 15          15  2016      9           1.75                6.1          958
# 16          16  2016      8           1.75                6.2          971
# 17          17  2016      7           1.75                6.1          949
# 18          18  2016      6           1.75                6.1          884
# 19          19  2016      5           1.75                6.1          866
# ...

# %%
df.drop(columns=['Unnamed: 0','year','month'],axis= 1, inplace=True)

# %%
df
# Out:
#     interest_rate  unemployment_rate  index_price
# 0            2.75                5.3         1464
# 1            2.50                5.3         1394
# 2            2.50                5.3         1357
# 3            2.50                5.3         1293
# 4            2.50                5.4         1256
# 5            2.50                5.6         1254
# 6            2.50                5.5         1234
# 7            2.25                5.5         1195
# 8            2.25                5.5         1159
# 9            2.25                5.6         1167
# 10           2.00                5.7         1130
# 11           2.00                5.9         1075
# 12           2.00                6.0         1047
# 13           1.75                5.9          965
# 14           1.75                5.8          943
# 15           1.75                6.1          958
# 16           1.75                6.2          971
# 17           1.75                6.1          949
# ...

# %%
df.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(df)
plt.show()

# %%
df.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
plt.scatter(df['interest_rate'],df['index_price'],color = 'r')
plt.xlabel('interest_rate')
plt.ylabel('unemployment_rate')
plt.show()

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X.head()
# Out:
#    interest_rate  unemployment_rate
# 0           2.75                5.3
# 1           2.50                5.3
# 2           2.50                5.3
# 3           2.50                5.3
# 4           2.50                5.4

# %%
y.head()
# Out:
# 0    1464
# 1    1394
# 2    1357
# 3    1293
# 4    1256
# Name: index_price, dtype: int64

# %%
# train test split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
new_x = x_train.columns[0]

# %%
sns.regplot(x = x_train[new_x],y = y_train)
plt.xlabel('interest_rate')
plt.ylabel('index_price')
plt.show()

# %%
new_x_2 = x_train.columns[1]

# %%
sns.regplot(x = x_train[new_x_2],y = y_train)
plt.xlabel('umployment_rate')
plt.ylabel('index_price')
plt.show()

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 288.89595281, -319.2044896 ])

# %%
model.predict(x_test)
# Out:
# array([1192.13083729,  824.23971817, 1400.41971162,  856.16016713,
#         992.22505325, 1160.21038833,  920.00106505, 1328.19572341])

# %%
r2_score(y_test,model.predict(x_test))
# Out:
# 0.864002429962521
