# %%
# import librasry
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
np.random.seed(42) 
x = 6 * np.random.rand(100,1) - 3

# %%
y = 0.5 * x**2 + 1.5*x + 2 + np.random.randn(100,1)
# quadratic equartion used = y = 0.5x^2+1.5x+2+outliers

# %%
x.shape
# Out:
# (100, 1)

# %%
y
# Out:
# array([[ 1.24123141],
#        [ 9.41400236],
#        [ 5.14848766],
#        [ 1.07556038],
#        [ 0.81431304],
#        [ 1.39117912],
#        [ 3.01586824],
#        [ 7.19084455],
#        [ 2.28557792],
#        [ 4.15019171],
#        [ 2.73776865],
#        [10.53261462],
#        [ 6.45154953],
#        [ 1.4137976 ],
#        [ 1.05573858],
#        [ 1.92347426],
#        [ 0.22590688],
#        [ 1.90617759],
#        [ 1.07876366],
#        [-0.55791779],
#        [ 3.52799559],
#        [ 1.3558642 ],
#        [ 0.91208454],
#        [ 0.88413428],
#        [ 0.22399635],
#        [ 5.60979425],
#        [ 0.57787459],
#        [ 1.32947982],
#        [ 2.82417355],
#        [ 2.02483468],
#        [ 5.06227568],
#        [ 1.16327328],
#        [ 1.74825683],
#        [ 9.59249198],
#        [ 8.17455451],
#        [ 6.4610229 ],
#        [ 0.98891816],
#        [ 3.75591024],
#        [ 4.07668882],
#        [ 1.82739082],
#        [ 1.13502407],
#        [ 0.78833287],
#        [ 2.85461239],
#        [ 9.4515941 ],
#        [ 1.66741953],
#        [ 3.02875598],
#        [ 2.34634294],
#        [ 0.78601019],
#        [ 3.04652291],
#        [ 3.14184658],
#        [ 9.20490033],
#        [ 5.27246295],
#        [ 9.53200959],
#        [ 7.85596596],
#        [ 1.50295568],
#        [ 9.06903275],
#        [ 0.28222038],
#        [ 1.40111375],
#        [ 0.7103493 ],
#        [ 2.52707826],
#        [ 0.43791174],
#        [ 0.56114254],
#        [ 7.7173851 ],
#        [-0.15073141],
#        [ 1.11968492],
#        [ 3.7242207 ],
#        [-0.51832779],
#        [ 6.54822096],
#        [ 1.68896737],
#        [11.4308653 ],
#        [ 4.54736207],
#        [-0.39811515],
#        [ 2.4727914 ],
#        [ 6.92742396],
#        [ 4.88242824],
#        [ 5.35150982],
#        [ 5.08598522],
#        [ 1.66453882],
#        [ 1.37983913],
#        [ 0.48448855],
#        [ 9.50689911],
#        [ 3.85715977],
#        [-0.19850267],
#        [ 2.15724241],
#        [-0.03274249],
#        [ 1.76383018],
#        [ 6.17399313],
#        [ 2.75793197],
#        [ 9.14709756],
#        [ 2.17661144],
#        [ 2.00316205],
#        [ 6.63451617],
#        [ 5.32583647],
#        [ 1.86534672],
#        [ 4.87080802],
#        [ 1.12904299],
#        [ 2.13679582],
#        [ 1.78352661],
#        [ 2.05954903],
#        [ 2.06569049]])

# %%
# visualization
plt.scatter(x,y,color = 'g')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
from sklearn.model_selection import train_test_split # train test split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()

# %%
linear_reg.fit(x_train,y_train)
# Out:
# LinearRegression()
